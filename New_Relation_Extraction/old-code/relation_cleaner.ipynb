# %%
import pickle as pkl
import os
import re

# %%
with open('only_CVEs_nieve.pkl', 'rb') as f:
    unique_relations=pkl.load(f)

# %%
len(unique_relations)
# Out:
# 4384

# %%
unique_relations[0]
# Out:
# 'Log4j2, CVE-2021-45046'

# %%
only_CVEs=[]
for items in unique_relations:
    if 'CVE' in items:
        only_CVEs.append(items)

print(len(only_CVEs))
# Out:
# 4384

# %%
only_CVEs[35]
# Out:
# 'Booking.com, CVE-2020-8913'

# %%
with open('only_CVEs_nieve.pkl', 'wb') as f:
    pkl.dump(only_CVEs, f)
