# %%
import json
import pandas as pd
import re
from tqdm.auto import tqdm
from ast import literal_eval

# %%
with open('hackerNews_updated.json', 'r') as f:
    file=json.load(f)

# %%
file['4']['content']

# %%
def remove_between_tags(text):
    # Remove everything between < and > including the symbols
    text = re.sub(r'<.*?>', '', text)
    # Remove any extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
for items in tqdm(file.keys()):
    content_list=file[items]['content']
    temp=[]
    for sentences in content_list:
        fixed=remove_between_tags(sentences)
        if fixed is not None:
            temp.append(remove_between_tags(sentences))
    file[items]['fixed_content']=temp

# %%
file['30']['fixed_content']

# %%
text_100=[]
count=0
for items in tqdm(file.keys()):
    count+=1
    if count==101:
        break
    text_100.append(file[items]['fixed_content'])
# {'text':}

# %%
len(text_100)

# %%
text_100[50]

# %%
dic={'text':text_100}
df=pd.DataFrame.from_dict(dic)
df.to_csv('Hacker_100.csv', index=False)

# %%
df=pd.read_csv('../Hacker_100.csv')

text_list=[]

for items in df.itertuples():
    print(items[1])
    text_list.append(literal_eval(items[1]))

# %%
len(text_list)

# %%
len(text_list[0])

# %%
df.head()

# %%
len(text_list[2])

# %%
text_list[2]

# %%
df=pd.read_csv('../Hacker_100.csv')

# %%
df.head()

# %%
software_list=[]

for items in df.itertuples():
    print(items[2])
    software_list.append(literal_eval(items[2]))

# %%
software_set=[]
for items in software_list:
    temp=[]
    for it in items:
        for i in it:
            print(i)
            if i is not None:
                temp.append(i)
    temp=list(set(temp))
    software_set.append(temp)

# %%
software_set

# %%
hardware_list=[]

for items in df.itertuples():
    print(items[3])
    hardware_list.append(literal_eval(items[3]))

# %%
hardware_set=[]
for items in hardware_list:
    temp=[]
    for it in items:
        for i in it:
            print(i)
            if i is not None:
                temp.append(i)
    temp=list(set(temp))
    hardware_set.append(temp)

# %%
hardware_set

# %%
vulnerability_list=[]

for items in df.itertuples():
    print(items[3])
    vulnerability_list.append(literal_eval(items[4]))

# %%
vulnerability_set=[]
for items in vulnerability_list:
    temp=[]
    for it in items:
        for i in it:
            #print(i)
            if i is not None:
                temp.append(i)
    temp=list(set(temp))
    vulnerability_set.append(temp)

# %%
vulnerability_set
# Out:
# [['data recovery', 'exclusion list', 'ransomware', '##ybersecurity'],
#  ['unauthorized data access',
#   'Posture Management',
#   'data leak',
#   'prospect and',
#   'multi - factor authentication',
#   '##ybersecurity'],
#  ['EA', '##ybersecurity', 'property theft', 'blend', 'zero - day'],
#  ['double theft',
#   'phing as - a - service',
#   'Stole log credentials',
#   'multi - factor authentication',
#   'AiTM',
#   'email',
#   '##ybersecurity'],
#  ['wiper maware',
#   'data',
#   'wipe',
#   'junk data',
#   'ma',
#   '##ybersecurity',
#   'corrupt',
#   '##read',
#   'shadow'],
#  ['ma', '##ybersecurity', 'skills assessment'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['power out',
#   'multi - event cyber attack',
#   'Sand',
#   'OT',
#   '##SC',
#   '##ybersecurity',
#   'Sandworm',
#   'Sand out',
#   'blackout',
#   'data wiping'],
#  ['SIEM',
#   'and',
#   'SIE',
#   'global data creation',
#   '- - fits - all',
#   'SOC',
#   'overworked security teams',
#   '##ybersecurity',
#   'automation'],
#  ['maware',
#   'security flaw',
#   'loss of confidentiality',
#   'remote access',
#   'Confluence',
#   '##ybersecurity',
#   'backdoor',
#   'forensic trail',
#   'bug',
#   'rogue',
#   'persistent backdoor'],
#  ['water hole', 'Israel', '##ybersecurity', 'Phi'],
#  ['Hu', 'h', 'intrusive permissions', '##ybersecurity', 'spy', 'Kamran'],
#  ['WAR',
#   'flaws',
#   'PowerShell script',
#   'backdoor access',
#   'data theft',
#   'ransomware',
#   'path traversal',
#   '##ybersecurity',
#   'code execution'],
#  ['E',
#   'multi - factor authentication',
#   'booby',
#   '-',
#   'ethical guardrail',
#   '##ybersecurity',
#   'Windows Report',
#   '##ep',
#   'cloaking',
#   'whitespace',
#   'drive - by download'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['MuC',
#   'Mu',
#   'remote administration',
#   'Phony',
#   '##ShellShell activity',
#   '##ybersecurity',
#   'Deep Inst'],
#  ['reflection DoS amlification',
#   '##ybersecurity',
#   'amlification attacks',
#   'sed UDP traffic'],
#  ['hides execution',
#   'mine',
#   'reverse shell',
#   'dummy test job',
#   'pip',
#   'crypto mine',
#   '##amrian',
#   '##ybersecurity',
#   'code execution',
#   '##oc',
#   'Cloud',
#   'Automation',
#   'bug',
#   'undetectable resources',
#   'mining'],
#  ['IP Address in Calls',
#   'masks',
#   'Silence Unknown Callers click attacks',
#   '##ony',
#   'privacy',
#   '##ybersecurity',
#   'silenced calls'],
#  ['suspicious code',
#   'transfer sh',
#   'Discord',
#   '- sourceelb',
#   '##ybersecurity',
#   'BS',
#   'code obfuscation',
#   'rogue',
#   'typosquat'],
#  ['AI',
#   'gen - AI',
#   'Gene AI',
#   'AI usage',
#   'Gen AI',
#   'gen AI usage',
#   '##ybersecurity',
#   '##CI',
#   'gen AI',
#   'Unchecked AI usage'],
#  ['##ybersecurity', 'security team'],
#  ['information steal', 'privilege escalation', '##ybersecurity', 'farnetwork'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['malware',
#   '##pto',
#   '##CS',
#   'KAN',
#   '##ybersecurity',
#   'R',
#   'ha',
#   '##coy document',
#   'maware'],
#  ['infinite loop',
#   'obfuscated',
#   'HP P',
#   'SEO poisoned',
#   'ofuscated PowerShell script',
#   'obfuscated JavaScript',
#   '##ybersecurity',
#   'Gootloader infection',
#   'beacon'],
#  ['malware attacks',
#   'has',
#   'file upload security',
#   'malicious file uploads',
#   'wild',
#   '##ybersecurity',
#   'confidence in la',
#   'File Upload Security',
#   'file upload',
#   'Data breach',
#   'backdoors',
#   'Deep CDR',
#   'cloud',
#   'file upload vnerlities',
#   'ma file uploadsware',
#   'Misconfiguration',
#   'file upload attacks',
#   'data loss',
#   'increased attack surface',
#   'Data Protection'],
#  ['SQL injection',
#   '##crime',
#   '##GPTAI PlaygroundGPT',
#   '##ybersecurity',
#   'snort rule'],
#  ['information stealing',
#   'ELF',
#   'SEQRITE',
#   'zero - day vulnerability',
#   '##ybersecurity'],
#  ['escalation',
#   'loss of confidentiality',
#   '- crime',
#   'Apache ActiveMQ',
#   'Confluence',
#   'wild',
#   '##ybersecurity',
#   '##ware',
#   'Atlas',
#   'CRB',
#   'remote code execution',
#   'Atlassian Connce',
#   'Ce'],
#  ['flaws', '##ybersecurity', 'restart'],
#  ['encrypted command - and - control',
#   'data theft',
#   'obfuscation',
#   'information steal',
#   'infections',
#   '##ybersecurity',
#   'stealer malware',
#   'maware'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['remote attackers',
#   'ransomware',
#   'arbitrary code execution',
#   '##ybersecurity',
#   'command',
#   'command injection',
#   'bug'],
#  ['Dropper malware',
#   'malware',
#   'guard',
#   'Restricted Settings bypass',
#   'installation error',
#   '##ybersecurity',
#   '##rop',
#   'maware',
#   'Restricted Settings'],
#  ['wipe ma',
#   'Agonizing Serpens',
#   'wiper maware',
#   'wipe',
#   '##ybersecurity',
#   'EDR'],
#  ['GCR', '##ybersecurity', 'Covert Channel', 'proof - of -'],
#  ['money laundering',
#   'ransomware',
#   'RansomedVC',
#   'border',
#   '##ybersecurity',
#   'Ghost',
#   '##ware',
#   'money laund',
#   'Counter Ransomware'],
#  ['malware',
#   '##C',
#   'persistent',
#   'ma',
#   '##ybersecurity',
#   'spy',
#   '##oc',
#   'B47',
#   'maware',
#   'Strip'],
#  ['support case management system',
#   'HAR',
#   '##ential',
#   'security event',
#   'token theft',
#   '##ybersecurity',
#   'Ok',
#   'authentic change'],
#  ['independent security reviewed',
#   'MASA',
#   'security badge',
#   'Independent security review',
#   '##ybersecurity',
#   'badge',
#   'issues',
#   'independent security'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['backdoor access',
#   'root privileges',
#   'Kinsing',
#   'b4sty',
#   'Linux privilege escalation',
#   'Kinsing maware',
#   '##ybersecurity',
#   '##nsing',
#   'remote code execution'],
#  ['data',
#   'scam',
#   '##Ste',
#   '##ybersecurity',
#   'two - factor authentication',
#   'Bit',
#   'NodeStealer'],
#  ['model maturity',
#   'malware behavior',
#   'predictive AI',
#   'ma',
#   '##ybersecurity',
#   '##PA',
#   '##ec',
#   'maware',
#   '##Lybersecurity cybersecurity'],
#  ['spyware',
#   'trojanized',
#   'speaker',
#   '##ybersecurity',
#   'spyes',
#   '##ware',
#   'maware',
#   'WhatsApp'],
#  ['Supply chain security',
#   'reverse shell',
#   'dependency trust',
#   '51',
#   'Telegram Desktop application',
#   'counter',
#   '##pm',
#   '##ybersecurity'],
#  ['kill switch',
#   'remote access passwords',
#   '##ybersecurity',
#   'switch',
#   'maware'],
#  ['least privilege',
#   'Shadow IT',
#   'Posture Management',
#   'try first',
#   'shadow element',
#   'shadow SaaS',
#   '##ybersecurity',
#   'shadow IT',
#   'pay later'],
#  ['remote administration',
#   'remote',
#   'Sandstor',
#   'MuddyW',
#   '##ybersecurity',
#   'Muddy',
#   'Ph'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['vulnerable',
#   'Bring Your Own V',
#   'memory - mapped',
#   'privilege',
#   'B',
#   'without privilege',
#   'kernel address space layout randomization',
#   '##ybersecurity',
#   'problem',
#   'terminating arbitrary processes',
#   'K'],
#  ['CVS', '##ybersecurity', 'C', '##VS'],
#  ['remote binaries',
#   'ActiveMQ',
#   'vulnerability',
#   'ransomware',
#   'CM',
#   '##ybersecurity',
#   'infections',
#   '##siexec',
#   '##ware',
#   'remote code execution',
#   'bug'],
#  ['attacks',
#   'aging',
#   'O',
#   'blackpumaoc',
#   'multiple accounts creation',
#   'pseudo - random',
#   'confirmation code',
#   'Koech',
#   '##ybersecurity',
#   '" - a - service',
#   '##ech',
#   'underground link shortening',
#   'maware',
#   'phone number verification'],
#  ['LayX',
#   'data leak',
#   'risk alert',
#   'paste',
#   'journey data upload policy',
#   'credential theft',
#   '##ybersecurity',
#   '##hing attacks',
#   'risky extensions',
#   'alert message',
#   'Investigate',
#   'unintentional data leak',
#   'Conditions',
#   'unmanaged',
#   'alert',
#   'detected',
#   'Action',
#   'prevent with bypass',
#   'Okta',
#   'block list',
#   'false',
#   'prevent upload',
#   'unmanaged devices',
#   'weak passwords',
#   'cential theft',
#   'leakage',
#   'data loss',
#   'ma access',
#   'blind spot',
#   'policy configuration',
#   'blind',
#   'weak'],
#  ['passive implants',
#   'malware',
#   'L',
#   'backdoor access',
#   'IOC',
#   'HTTPSno',
#   'otion',
#   '##ybersecurity',
#   '##do',
#   'espionage'],
#  ['maware',
#   'Lazarus',
#   'S',
#   'hijacking',
#   'KAN',
#   'S2W',
#   '##ybersecurity',
#   'S2',
#   '##ptoc',
#   'defense evasion',
#   'arage b'],
#  ['##P',
#   'arbitrary command execution',
#   '##ybersecurity',
#   'steal',
#   'U',
#   'data theft',
#   'maware'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['Known Exploited Vulnerabilities',
#   'SQL injection',
#   'Ex',
#   '##ybersecurity',
#   'code execution'],
#  ['APK maware',
#   'Ari',
#   'intrusive permission',
#   'honey trap',
#   '##ybersecurity',
#   'security',
#   'Ski',
#   '##AG',
#   'maware'],
#  ['now-removed packages',
#   'Ser',
#   '##line tasks',
#   '##ybersecurity',
#   'inline tasks',
#   'maware'],
#  ['white - labeling',
#   'repetitive',
#   'Performance',
#   'JavaScript alerts',
#   'sick leave',
#   'block',
#   'Activity logging',
#   'B',
#   '##ybersecurity',
#   '##test',
#   'XSS',
#   'CSRF'],
#  ['##fluence Data Center and Server',
#   'improper authorization vulnerability',
#   'data loss',
#   '##ybersecurity',
#   'CVE-2023-22515',
#   'bug'],
#  ['Malwareby', 'deluge', '##ybersecurity', '##ware', '##hishing', 'PyCharm'],
#  ['##ybersecurity', '##sky', 'theft', 'Kaspersky'],
#  ['no ads', '##ybersecurity', 'behavioral advertising'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['overwriting files',
#   '##hu',
#   'destructive malware',
#   '##ybersecurity',
#   'corrupt',
#   'nohup command',
#   'root permissions'],
#  ['data leak',
#   'file uploads',
#   '##ybersecurity',
#   'data breach',
#   'security',
#   'Content Disarm and Reconstruction',
#   'maware',
#   'Disarm and Reconstruction'],
#  ['unintended access',
#   'General Information | Potential Public List Widget Misconfiguration',
#   'data leak',
#   'configuration issue',
#   'SSPM',
#   '##ure',
#   'app exposure',
#   'ServiceNow Security',
#   'application misconfiguration',
#   'Access Control List',
#   'misconfiguration',
#   'data leakage',
#   'fix',
#   '##ybersecurity',
#   'unauthenticated users',
#   'misconfigurations'],
#  ['EC2',
#   'exposed',
#   'IAM',
#   'AWS IAM',
#   '##ptomining',
#   '##ing',
#   'EC',
#   'cryptojacking',
#   '##ybersecurity',
#   'A IAM',
#   'blindsp',
#   '##pt'],
#  ['##gress',
#   'client credential',
#   '##ybersecurity',
#   'unauthorized access',
#   '##GIN'],
#  ['poisoning',
#   'stomping',
#   'module stomping',
#   '##ybersecurity',
#   'stolen',
#   'VBoxSVC',
#   'GH',
#   'DLL side-loading',
#   'T',
#   'code signing',
#   'g'],
#  ['DoS attack',
#   'unencrypted server - side message history',
#   'password',
#   'Certificate has expired',
#   'lifetime',
#   'MiTM',
#   'spoofing attack',
#   'jabber',
#   'jab',
#   'Control Plane denial-of-service',
#   '##ybersecurity',
#   'server breach',
#   'Mi'],
#  ['LP',
#   'SIGN',
#   'software',
#   'Lazarus Group',
#   '##ybersecurity',
#   '##do',
#   'SIGNBT',
#   'SIGNBT ma',
#   'dump'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['and',
#   '##is detection',
#   'data leak',
#   'cybersecurity',
#   'ransomware attacks',
#   'anomaly detection',
#   'cyber crisis',
#   'Fidelis Deception',
#   'Cyber incidents',
#   '##ybersecurity',
#   'unauthorized access',
#   '##delis NDR',
#   'Vulnerability management Management',
#   'cyber incident reporting',
#   '##yber incidents',
#   'Management'],
#  ['##ybersecurity', 'unfair bias', 'AI', 'known vulnerabilities'],
#  ['F',
#   'authentication bypass',
#   'IP',
#   '##ybersecurity',
#   'C',
#   'request smuggling',
#   'remote code execution',
#   'bug'],
#  ['side - channel exploit',
#   'speculative execution',
#   '##Asly',
#   '##ybersecurity',
#   '##mail',
#   'autofilled',
#   'Spectre',
#   'race conditions',
#   '##eak',
#   '##redicting sensitive instructions',
#   'information leak',
#   'spare',
#   'covert channel',
#   'data corruption',
#   'rogue',
#   'prediction',
#   '##Leakage',
#   'mispredicting sensitive instructions',
#   'information leakage',
#   'misprediction'],
#  ['multi - factor authentication',
#   'Scattered Spider',
#   '##ev',
#   'theft',
#   'privilege escalation',
#   '##ybersecurity',
#   'FIDO',
#   'stolen password policy'],
#  ['HTTP DDoS',
#   'Rapid Reset',
#   'S',
#   'ransom DDoS',
#   'DDoS',
#   '##ybersecurity',
#   'HTTP DDS',
#   'DDoS attacks'],
#  ['Configuration drift',
#   'privacy violations',
#   'data leak',
#   'forgotten and misconfigured pixel',
#   'rogue pixel',
#   '##ybersecurity',
#   'forgotten rogue pixel',
#   'Reflectiz',
#   'configuration drift',
#   'rogue'],
#  ['Microsoft Excel decoy', 'mal', 'and -', '##MAPL', '##ybersecurity'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['SYSTEM',
#   'Mirth',
#   'vulnerability',
#   '##EM',
#   '##aw',
#   '##ybersecurity',
#   'remote command execution',
#   'RCE',
#   'remote code execution'],
#  ['commodity malware',
#   'Yo',
#   'SturgePhisher',
#   'mail',
#   '##ybersecurity',
#   'NordVP',
#   'data theft'],
#  ['V',
#   'vulnerability',
#   'Winter Viver',
#   'XSS flaw',
#   'cross - site scripting',
#   '##ybersecurity',
#   'XSS',
#   'stored cross-site scripting'],
#  ['unauthorized account access',
#   'responsible disclosure',
#   'token reuse attack',
#   'identity theft',
#   'cross - application access',
#   'B',
#   'absence of token verification',
#   'token verification',
#   'H P',
#   '##ybersecurity',
#   'security breach',
#   'access token'],
#  ['Cloud Data Events',
#   'leaked access keys',
#   'S',
#   'ransomware',
#   '##3',
#   '##ybersecurity',
#   'S3 ransomware',
#   'deep dive',
#   'for'],
#  ['vCenter Server',
#   'partial information disclosure',
#   'information disclosure',
#   'out bounds write vulnerability',
#   '##aw',
#   '##ybersecurity',
#   'remote code execution',
#   'in - the - wild'],
#  ['QR code',
#   'clip steal',
#   'fraud',
#   'IP',
#   'ma',
#   'injector malware',
#   'malvertising',
#   'steal maware',
#   '##PIX',
#   'information steal',
#   '##ybersecurity',
#   'additional guardrail',
#   'cloaking',
#   '##pp web',
#   'maware'],
#  ['buffer over-read',
#   'vulnerability',
#   'wild',
#   'Operations for Logs',
#   '##ybersecurity',
#   'buffer overflow',
#   'session hijacking',
#   'Ex',
#   'hijacking',
#   'multi - factor authentication checks',
#   'session cookie',
#   'Citrix Bleed',
#   'HP GE',
#   'not understanding snprintf',
#   '##aw',
#   'patch bypass',
#   'RDP',
#   'K',
#   'buffer over -',
#   'multi - factor authentic',
#   'remote code execution',
#   'AP',
#   'defense in depth'],
#  ['Shadow IT',
#   'email auto - forwarding',
#   'Auto - forwarding emails',
#   'shadow IT risks',
#   '##ybersecurity',
#   'auto-email forwarding'],
#  ['file transfer',
#   '##ke',
#   'unspecified cryptographic program',
#   'share',
#   '##ybersecurity',
#   'Sebastian',
#   'online covert',
#   'information'],
#  ['SIM swap',
#   'money laundering',
#   'false documentation',
#   'Money Laundering',
#   'intrusive permissions',
#   'cross - referenced information',
#   'unauthorized access',
#   'son in distress',
#   '##ybersecurity'],
#  ['Product access',
#   'error handling',
#   'outdated API management',
#   'management',
#   'ghosts',
#   '##ybersecurity',
#   'unauthorized access',
#   'data breach',
#   'error',
#   'security incidents',
#   'native API management']]

# %%
df.columns
# Out:
# Index(['text', 'Software', 'Hardware', 'Vulnerability'], dtype='object')

# %%
df['Software']=software_set
df['Hardware']=hardware_set
df['Vulnerability']=vulnerability_set

# %%
df.head()
# Out:
#                                                 text  \
# 0  ['The threat actors behind a new ransomware gr...
# 1  ['Effective marketing operations today are dri...
# 2  ['Cybersecurity researchers have discovered wh...
# 3  ['Malaysian law enforcement authorities have a...
# 4  ['Cybersecurity researchers have warned about ...
#
#                                             Software  \
# 0  [group, Bitdefender, Hunters International, da...
# 1  [Outreach, workflow, apps, Marketing Automatio...
# 2  [ShadowPad, Targeted organizations, Barracuda ...
# 3  [BulletP, syndicate, New Straits Times, Des, D...
# 4  [Karma, Wiper, wipe, BlackBerry, BiBi-Linux, L...
#
#                                             Hardware  \
# 0  [affiliates, command line parameters, ransomwa...
# 1  [credit cards, public links, project managemen...
# 2  [Targeted organizations, RedHotel, cyecurity, ...
# 3  [New Straits Times, platform, Intel 471, cyecu...
# 4  [Moses Staff, Wiper, B W, wiper malware, Secur...
#
#                                        Vulnerability
# 0  [data recovery, exclusion list, ransomware, ##...
# 1  [unauthorized data access, Posture Management,...
# 2  [EA, ##ybersecurity, property theft, blend, ze...
# 3  [double theft, phing as - a - service, Stole l...
# 4  [wiper maware, data, wipe, junk data, ma, ##yb...

# %%
df.to_csv("../Hacker_100.csv",index=False)
